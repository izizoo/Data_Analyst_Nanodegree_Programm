# %% [markdown]
# # Titanic Data Visualization:

# %% [markdown]
# ## Summary:

# %% [markdown]
# > Data visualization story of titanic incident created using tableau.
# > The tableau story shows a multiple graphs representing the passengers data like thier ages and classes and so on.
# > With these graphs we may find intresting thoughts like the chance of surviving or being dead which draws conclusion that female of first class had higher chances of survival and males of third class had least chances of survival. In general, females had higher chances of survival than males.

# %% [markdown]
# ## Design:

# %% [markdown]
# > I used multiple chart types like bubble chart, bar chart, table chart and make use of color, markers and filters to visualize my data. I also created new data-type which involved breaking continuous age data into bins of width 3 but after collecting the feedback I changed it to 10.

# %% [markdown]
# #### let's start with the story part by part:

# %% [markdown]
# > - "All passengers from the selected sample": at this dashboard I choosed two types of charts to represent the passengers were in board, the first one was only marks each one represent one passenger, and the secound one is a table which give a first look to the sample data.

# %%
from IPython.display import Image
Image("/Users/Abdulaziz/Desktop/p1.png", width ="300")

# %% [markdown]
# > - "Passengers ages": At this chart I choosed column type to show the distribution of age for the passengers with showing the state of surviving and we can see that most of passengers were from 20 - 30 years old.

# %%
from IPython.display import Image
Image("/Users/Abdulaziz/Desktop/p2.png", width ="300")

# %% [markdown]
# > - "Average age of passengers based on sex and passenger class": At this chart I choosed column type with double charts to visualize the data which is the average age of passengers based on their sex and class on the top part and the bottom part is the same thing but without dividing the data by sex.

# %%
from IPython.display import Image
Image("/Users/Abdulaziz/Desktop/p3.png", width ="100")

# %% [markdown]
# > - "Passengers avg fare over the starting point of titianic trip": This chart (Bubble) represent the average fare for the passengers and the count with showing the chart as three parts for each starting point and at the bottom same thing but with specifying the passenger class.

# %%
from IPython.display import Image
Image("/Users/Abdulaziz/Desktop/p4.png", width ="300")

# %% [markdown]
# > - "Count of all passengers with keeping in mind the surviving and the passenger class": For this chart I'm using bar type to represent the count of all passengers of the selected sample with based on the class and the surviving status.

# %%
from IPython.display import Image
Image("/Users/Abdulaziz/Desktop/p5.png", width ="500")

# %% [markdown]
# > #### Note: all dashboads on the sotry have a filter and labels, the images above just a peek.

# %% [markdown]
# >The story URL (before feedback): https://public.tableau.com/profile/abdulaziz5265#!/vizhome/TitanicTableauStory/Story1

# %% [markdown]
# ## Feedback:

# %% [markdown]
# > 1- What do you notice in the visualization?
#
# > I see most dead people is men and from the 3rd class.

# %% [markdown]
# > 2- What questions do you have about the data?
#
# > There is a few people in this data, where is the rest of them?

# %% [markdown]
# > 3- What relationships do you notice?
#
# > if I'm a woman in the 1st class I'll have a better chance to survive.

# %% [markdown]
# > 4- Is there something you don’t understand in the graphic?
#
# > Yes actually there are many things:
# - In the secound part of the story at "Passengers Ages"the ages is not clear to me at the bottom of the chart.
# - The value of each column is not specified at "Passengers Ages" like others charts.
# - In the 4th part of the story, I think it's better if there is a count of passengers including the avg fare for each location.

# %% [markdown]
# ## Process Feedback:

# %% [markdown]
# > In the 1st and 3rd questions, I got a good feedback and there is nothing to add.

# %% [markdown]
# > About the 2nd question: the number of people in this study it's only a sample selected from the whole titanic popultion which is 891.

# %% [markdown]
# > 4th question:
#
# > - The ages is not clear probably becuase of the bin size so I changed it from 2 to 10 so each column now represent 10 years.
#
# > - Now each coulmn hold a value on it to be clear to the people who see this chart.
#
# > - The count of each location has been added inside the bubbles now.

# %% [markdown]
# > Final Titanic Story URL (After Feedback): https://public.tableau.com/profile/abdulaziz5265#!/vizhome/TitanicTableauStory-afterfeedback/Story1

# %% [markdown]
# ## Resources:

# %% [markdown]
# > - https://github.com/
# > - https://public.tableau.com/
# > - https://classroom.udacity.com/
